# %%
from data.data_utils import *

# %%
bucket_name = 'benchmark-public-data'

blob_name = 'kaggle'

# %%
list_blobs(bucket_name, blob_name)
# Out:
# ...
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 list_blobs(bucket_name, blob_name)
#
# File ~/Documents/aideml/data/data_utils.py:55, in list_blobs(bucket_name, prefix)
#      53 # Note: The call returns a response only when the iterator is consumed.
#      54 avalable_files = []
# ---> 55 for blob in blobs:
#      56     if blob.name.startswith(prefix) and len(blob.name) > 4:
#      57         avalable_files.append(blob.name)
#
# File ~/Documents/aideml/.venv/lib/python3.11/site-packages/google/api_core/page_iterator.py:208, in Iterator._items_iter(self)
#     206 def _items_iter(self):
#     207     """Iterator for each item returned."""
# --> 208     for page in self._page_iter(increment=False):
#     209         for item in page:
#     210             self.num_results += 1
#
# ...

# %%
download_blob(bucket_name, blob_name, "test")
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 download_blob(bucket_name, blob_name, "test")
#
# File ~/Documents/aideml/data/data_utils.py:35, in download_blob(bucket_name, source_blob_name, destination_file_name)
#      30 # Construct a client side representation of a blob.
#      31 # Note `Bucket.blob` differs from `Bucket.get_blob` as it doesn't retrieve
#      32 # any content from Google Cloud Storage. As we don't need additional data,
#      33 # using `Bucket.blob` is preferred here.
#      34 blob = bucket.blob(source_blob_name)
# ---> 35 blob.download_to_filename(destination_file_name)
#      37 print(
#      38     "Downloaded storage object {} from bucket {} to local file {}.".format(
#      39         source_blob_name, bucket_name, destination_file_name
#      40     )
#      41 )
#
# ...
